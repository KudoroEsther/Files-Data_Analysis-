# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
sales = pd.read_csv("sales_data.xls")
sales.head()
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 1  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 3  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id                              order_id  event_id  \
# 0        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 1        5          3202  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 2        9          3203  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 3       12          3204  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 4        6          3205  9e950ce3-2e12-479c-a051-493c1a497d49     14786
#
#               event_timestamp  quantity currency              checked_out_at  \
# 0  2024-03-26 22:05:58.863661         2      NGN  2024-03-30 04:19:10.406794
# 1  2024-03-26 22:05:58.863661         4      NGN  2024-03-30 04:19:10.406794
# 2  2024-03-26 22:05:58.863661         5      NGN  2024-03-30 04:19:10.406794
# 3  2024-03-26 22:05:58.863661         1      NGN  2024-03-30 04:19:10.406794
# 4  2024-03-26 22:05:58.863661         2      NGN  2024-03-30 04:19:10.406794
#
#     status      location
# 0  success  Saint Helena
# 1  success  Saint Helena
# 2  success  Saint Helena
# 3  success  Saint Helena
# 4  success  Saint Helena

# %%
sales.isna().sum()
# Out:
# customer_id        0
# device_id          0
# item_id            0
# line_item_id       0
# order_id           0
# event_id           0
# event_timestamp    0
# quantity           0
# currency           0
# checked_out_at     0
# status             0
# location           0
# dtype: int64

# %%
sales.shape
# Out:
# (578320, 12)

# %%
#Using loc
[0,2,4,6]
#extracts rows with the specified index numbers. Loc works with both integers and string
sales.loc[[0,2,4,6]]
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 6  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id                              order_id  event_id  \
# 0        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 2        9          3203  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 4        6          3205  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 6        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14787
#
#               event_timestamp  quantity currency              checked_out_at  \
# 0  2024-03-26 22:05:58.863661         2      NGN  2024-03-30 04:19:10.406794
# 2  2024-03-26 22:05:58.863661         5      NGN  2024-03-30 04:19:10.406794
# 4  2024-03-26 22:05:58.863661         2      NGN  2024-03-30 04:19:10.406794
# 6  2024-03-27 07:14:33.987347         2      NGN  2024-03-30 04:19:10.406794
#
#     status      location
# 0  success  Saint Helena
# 2  success  Saint Helena
# 4  success  Saint Helena
# 6  success  Saint Helena

# %%
#Using iloc
#iloc works with only integers
sales.iloc[[0,2,4,6]]
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 6  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id                              order_id  event_id  \
# 0        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 2        9          3203  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 4        6          3205  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 6        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14787
#
#               event_timestamp  quantity currency              checked_out_at  \
# 0  2024-03-26 22:05:58.863661         2      NGN  2024-03-30 04:19:10.406794
# 2  2024-03-26 22:05:58.863661         5      NGN  2024-03-30 04:19:10.406794
# 4  2024-03-26 22:05:58.863661         2      NGN  2024-03-30 04:19:10.406794
# 6  2024-03-27 07:14:33.987347         2      NGN  2024-03-30 04:19:10.406794
#
#     status      location
# 0  success  Saint Helena
# 2  success  Saint Helena
# 4  success  Saint Helena
# 6  success  Saint Helena

# %%
sales.columns
# Out:
# Index(['customer_id', 'device_id', 'item_id', 'line_item_id', 'order_id',
#        'event_id', 'event_timestamp', 'quantity', 'currency', 'checked_out_at',
#        'status', 'location'],
#       dtype='object')

# %%
#indexing columns
#this prints out the rows, columns based on the specified row indexes and column names
sales.loc[[0,2,4,7], ["customer_id", "device_id", "item_id"]]
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 7  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id
# 0        4
# 2        9
# 4        6
# 7        5

# %%
#prints out the rows with index number 0,2,4,7 and columns with index number 0,1,2,3
sales.iloc[[0,2,4,7], [0,1,2,3]]
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 7  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id
# 0        4          3201
# 2        9          3203
# 4        6          3205
# 7        5          3202

# %%
#Slicing using iloc and loc

#these prints out all the rows and columns
sales.iloc[::]
sales.iloc[:]
sales.iloc[0:-1]
# Out:
#              Sales Person      Geography              Product       Date  \
# 0            Barr Faughny    New Zealand      Raspberry Choco 2021-01-01
# 1     Dennison Crosswaite         Canada           White Choc 2021-01-01
# 2        Karlen McCaffrey            USA      99% Dark & Pure 2021-01-01
# 3            Barr Faughny    New Zealand  Baker's Choco Chips 2021-01-01
# 4          Beverie Moffet            USA   Manuka Honey Choco 2021-01-01
# ...                   ...            ...                  ...        ...
# 3785      Roddy Speechley           UK         70% Dark Bites 2022-01-04
# 3786          Van Tuxwell         India         Drinking Coco 2022-01-19
# 3787  Rafaelita Blaksland     Australia       Mint Chip Choco 2022-01-18
# 3788        Kelci Walkden     Australia   Spicy Special Slims 2022-01-03
# 3789      Gunar Cockshoot   New Zealand       Mint Chip Choco 2022-01-21
#
#       Amount  Boxes
# 0       8414    495
# 1        532     54
# 2       5376    269
# 3        259     22
# 4       5530    179
# ...      ...    ...
# 3785    8225    412
# 3786   10682   1526
# 3787   11746    511
# 3788    8862   1477
# 3789   11592    527
#
# [3790 rows x 6 columns]

# %%
#Using loc
#these prints out all the rows and columns
sales.loc[:]
sales.loc[::]
sales.loc[-1:] #[:-1] prints out just the column headers
# Out:
#              Sales Person      Geography              Product       Date  \
# 0            Barr Faughny    New Zealand      Raspberry Choco 2021-01-01
# 1     Dennison Crosswaite         Canada           White Choc 2021-01-01
# 2        Karlen McCaffrey            USA      99% Dark & Pure 2021-01-01
# 3            Barr Faughny    New Zealand  Baker's Choco Chips 2021-01-01
# 4          Beverie Moffet            USA   Manuka Honey Choco 2021-01-01
# ...                   ...            ...                  ...        ...
# 3786          Van Tuxwell         India         Drinking Coco 2022-01-19
# 3787  Rafaelita Blaksland     Australia       Mint Chip Choco 2022-01-18
# 3788        Kelci Walkden     Australia   Spicy Special Slims 2022-01-03
# 3789      Gunar Cockshoot   New Zealand       Mint Chip Choco 2022-01-21
# 3790       Mallorie Waber         USA     Spicy Special Slims 2022-01-07
#
#       Amount  Boxes
# 0       8414    495
# 1        532     54
# 2       5376    269
# 3        259     22
# 4       5530    179
# ...      ...    ...
# 3786   10682   1526
# 3787   11746    511
# 3788    8862   1477
# 3789   11592    527
# 3790    3871    431
#
# [3791 rows x 6 columns]

# %%
sales.columns
# Out:
# Index(['Sales Person', 'Geography', 'Product', 'Date', 'Amount', 'Boxes'], dtype='object')

# %%
#Using loc and iloc to slice columns
#this prints out rows from index number 0 to 4 and columns from sales person to amount
sales.loc[0:4, "Sales Person": "Amount"]
# Out:
#           Sales Person      Geography              Product       Date  Amount
# 0         Barr Faughny    New Zealand      Raspberry Choco 2021-01-01    8414
# 1  Dennison Crosswaite         Canada           White Choc 2021-01-01     532
# 2     Karlen McCaffrey            USA      99% Dark & Pure 2021-01-01    5376
# 3         Barr Faughny    New Zealand  Baker's Choco Chips 2021-01-01     259
# 4       Beverie Moffet            USA   Manuka Honey Choco 2021-01-01    5530

# %%
#using iloc for integers and index numbers
sales.iloc[0:4, 0:5]
# Out:
#           Sales Person      Geography              Product       Date  Amount
# 0         Barr Faughny    New Zealand      Raspberry Choco 2021-01-01    8414
# 1  Dennison Crosswaite         Canada           White Choc 2021-01-01     532
# 2     Karlen McCaffrey            USA      99% Dark & Pure 2021-01-01    5376
# 3         Barr Faughny    New Zealand  Baker's Choco Chips 2021-01-01     259

# %%
sales.columns
# Out:
# Index(['Sales Person', 'Geography', 'Product', 'Date', 'Amount', 'Boxes'], dtype='object')

# %%
#this strips all white spaces from the specified column
sales["Geography"] = sales["Geography"].str.strip()

# %%
#this prints out all of the rows and columns with index number 1 to 3
sales.iloc[0:-1, 1:4]
# Out:
#         Geography              Product       Date
# 0     New Zealand      Raspberry Choco 2021-01-01
# 1          Canada           White Choc 2021-01-01
# 2             USA      99% Dark & Pure 2021-01-01
# 3     New Zealand  Baker's Choco Chips 2021-01-01
# 4             USA   Manuka Honey Choco 2021-01-01
# ...           ...                  ...        ...
# 3785           UK       70% Dark Bites 2022-01-04
# 3786        India        Drinking Coco 2022-01-19
# 3787    Australia      Mint Chip Choco 2022-01-18
# 3788    Australia  Spicy Special Slims 2022-01-03
# 3789  New Zealand      Mint Chip Choco 2022-01-21
#
# [3790 rows x 3 columns]

# %%
#indexing using loc and iloc
#this sets Geography as the index
sales.set_index("Geography", inplace=True)

# %%
sales.head(3)
# Out:
#                     Sales Person          Product       Date  Amount  Boxes
# Geography
# New Zealand         Barr Faughny  Raspberry Choco 2021-01-01    8414    495
# Canada       Dennison Crosswaite       White Choc 2021-01-01     532     54
# USA             Karlen McCaffrey  99% Dark & Pure 2021-01-01    5376    269

# %%
#this prints out the index, in this case 'Geography'
sales.index
# Out:
# Index(['New Zealand', 'Canada', 'USA', 'New Zealand', 'USA', 'India', 'UK',
#        'Australia', 'Australia', 'New Zealand',
#        ...
#        'New Zealand', 'India', 'India', 'USA', 'UK', 'India', 'Australia',
#        'Australia', 'New Zealand', 'USA'],
#       dtype='object', name='Geography', length=3791)

# %%
#creates a a list of all locations
unique_index = sales.index.unique().sort_values()
unique_index
# Out:
# Index(['Australia', 'Canada', 'India', 'New Zealand', 'UK', 'USA'], dtype='object', name='Geography')

# %%
#prints out the top locations with the highest patronage
sales.index.value_counts().head(10)
# Out:
# Geography
# New Zealand    647
# Canada         643
# UK             636
# India          629
# Australia      627
# USA            609
# Name: count, dtype: int64

# %%
sales.index.value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Geography'>

# %%
#top ten countries with the most patronage received
sales.index.value_counts().head(100).plot(kind='bar', figsize=(5,5))
# Out:
# <Axes: xlabel='Geography'>

# %%
unique_index.nunique()
# Out:
# 6

# %%
len(sales.columns)
# Out:
# 5

# %%
#This prints out all instances of australia
sales.loc["Australia"]
# Out:
#                   Sales Person               Product       Date  Amount  Boxes
# Geography
# Australia       Dotty Strutley   Organic Choco Syrup 2021-01-01    1036     37
# Australia          Brien Boise  Caramel Stuffed Bars 2021-01-01    4039    176
# Australia  Rafaelita Blaksland         85% Dark Bars 2021-01-05    9730    573
# Australia       Andria Kimpton          Orange Choco 2021-01-06     539     77
# Australia       Andria Kimpton         85% Dark Bars 2021-01-07    5467    288
# ...                        ...                   ...        ...     ...    ...
# Australia          Van Tuxwell   Organic Choco Syrup 2022-01-07    9527    794
# Australia      Roddy Speechley   Organic Choco Syrup 2022-01-19    4872    325
# Australia       Dotty Strutley        70% Dark Bites 2022-01-07   13209    629
# Australia  Rafaelita Blaksland       Mint Chip Choco 2022-01-18   11746    511
# Australia        Kelci Walkden   Spicy Special Slims 2022-01-03    8862   1477
#
# [627 rows x 5 columns]

# %%
#Prints out the first 3 columns
sales.iloc[0:3]
# Out:
#                     Sales Person          Product       Date  Amount  Boxes
# Geography
# New Zealand         Barr Faughny  Raspberry Choco 2021-01-01    8414    495
# Canada       Dennison Crosswaite       White Choc 2021-01-01     532     54
# USA             Karlen McCaffrey  99% Dark & Pure 2021-01-01    5376    269

# %% [markdown]
# ### Filtering/Masking

# %% [markdown]
# And in pandas is written as &, OR in pandas is written as |

# %%
sales.head()
# Out:
#                     Sales Person              Product       Date  Amount  \
# Geography
# New Zealand         Barr Faughny      Raspberry Choco 2021-01-01    8414
# Canada       Dennison Crosswaite           White Choc 2021-01-01     532
# USA             Karlen McCaffrey      99% Dark & Pure 2021-01-01    5376
# New Zealand         Barr Faughny  Baker's Choco Chips 2021-01-01     259
# USA               Beverie Moffet   Manuka Honey Choco 2021-01-01    5530
#
#              Boxes
# Geography
# New Zealand    495
# Canada          54
# USA            269
# New Zealand     22
# USA            179

# %%
#Filtering
#this prints out all the sales for the specified sales person
sales[sales["Sales Person"] == "Barr Faughny"]
# Out:
#              Sales Person              Product       Date  Amount  Boxes
# Geography
# New Zealand  Barr Faughny      Raspberry Choco 2021-01-01    8414    495
# New Zealand  Barr Faughny  Baker's Choco Chips 2021-01-01     259     22
# Australia    Barr Faughny            Milk Bars 2021-01-11    7238    315
# Canada       Barr Faughny       70% Dark Bites 2021-01-12     490     35
# USA          Barr Faughny           White Choc 2021-01-18    2331    167
# ...                   ...                  ...        ...     ...    ...
# New Zealand  Barr Faughny  Baker's Choco Chips 2022-01-07    6566    299
# USA          Barr Faughny         Orange Choco 2022-01-07    1288     81
# Canada       Barr Faughny   Smooth Sliky Salty 2022-01-24   10794    771
# India        Barr Faughny           White Choc 2022-01-31    2485    355
# India        Barr Faughny              Eclairs 2022-01-10    2814    282
#
# [150 rows x 5 columns]

# %%
#Total number of products
sales["Product"].nunique()
# Out:
# 25

# %%
#top 20 products with the highest purchases
sales["Product"].value_counts().sort_values(ascending=False).head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='Product'>

# %%
sales.columns
# Out:
# Index(['Sales Person', 'Product', 'Date', 'Amount', 'Boxes'], dtype='object')

# %%
#this stores all instances of Karlen McCaffrey into the variable
mask = (sales['Sales Person'] == "Karlen McCaffrey" )

# %%
sales[mask].head()
# Out:
#                Sales Person          Product       Date  Amount  Boxes
# Geography
# USA        Karlen McCaffrey  99% Dark & Pure 2021-01-01    5376    269
# USA        Karlen McCaffrey  Raspberry Choco 2021-01-01    3052    204
# UK         Karlen McCaffrey     Orange Choco 2021-01-04     147     11
# India      Karlen McCaffrey    85% Dark Bars 2021-01-08    9562    479
# UK         Karlen McCaffrey        Milk Bars 2021-01-14    6881    222

# %%
sales.loc[mask].head(1)
# Out:
#                Sales Person          Product       Date  Amount  Boxes
# Geography
# USA        Karlen McCaffrey  99% Dark & Pure 2021-01-01    5376    269

# %%
#this prints out columns from Product to Amount for instance stored in mask
sales.loc[mask, "Product":"Amount"].head(3)
# Out:
#                    Product       Date  Amount
# Geography
# USA        99% Dark & Pure 2021-01-01    5376
# USA        Raspberry Choco 2021-01-01    3052
# UK            Orange Choco 2021-01-04     147

# %%
#Applying multiple filters
mask2 = (sales["Sales Person"] == "Karlen McCaffrey") & (sales["Amount"] >= 100)

# %%
sales.loc[mask2]
# Out:
#                Sales Person             Product       Date  Amount  Boxes
# Geography
# USA        Karlen McCaffrey     99% Dark & Pure 2021-01-01    5376    269
# USA        Karlen McCaffrey     Raspberry Choco 2021-01-01    3052    204
# UK         Karlen McCaffrey        Orange Choco 2021-01-04     147     11
# India      Karlen McCaffrey       85% Dark Bars 2021-01-08    9562    479
# UK         Karlen McCaffrey           Milk Bars 2021-01-14    6881    222
# ...                     ...                 ...        ...     ...    ...
# Australia  Karlen McCaffrey       85% Dark Bars 2022-01-25    6580   1316
# UK         Karlen McCaffrey           Milk Bars 2022-01-04   10171    566
# Australia  Karlen McCaffrey      70% Dark Bites 2022-01-25    9457    412
# UK         Karlen McCaffrey  Manuka Honey Choco 2022-01-28    8008    572
# Canada     Karlen McCaffrey     Raspberry Choco 2022-01-10    2331    138
#
# [154 rows x 5 columns]

# %%
sales.loc[mask].value_counts()
# Out:
# Sales Person      Product         Date        Amount  Boxes
# Karlen McCaffrey  50% Dark Bites  2021-04-13  5397    416      1
#                                   2021-05-25  2737    343      1
#                                   2021-07-07  8715    727      1
#                                   2021-07-12  7091    546      1
#                                   2021-10-06  18165   1514     1
#                                                               ..
#                   White Choc      2021-04-28  11564   1285     1
#                                   2021-10-25  952     74       1
#                                   2021-11-09  4550    380      1
#                                   2021-11-12  11557   964      1
#                   White-Choc      2022-01-07  5425    905      1
# Name: count, Length: 155, dtype: int64
